# %% [markdown]
# Article: https://www.cs.cmu.edu/~gtzan/work/pubs/tsap02gtzan.pdf
#
# MFCC: https://www.geeksforgeeks.org/nlp/mel-frequency-cepstral-coefficients-mfcc-for-speech-recognition/

# %%
#sklearn syntax
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5,metric='euclidean')
knn.fit(X_train, y_train)

# %% [markdown]
# First attemp: Only MFCC features used, 12 features with equal weights resulting in 24 parameters in total (means and variances)
# Train/Validation/Test split 70/20/10, best model retrained on validation+train data
# Result: 66% accuracy
